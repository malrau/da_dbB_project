# %% [markdown]
# <h2>
# <center>
# GRADING SCHEMA
# </center>
# </h2>

# %% [markdown]
# <h3>
# Import required modules
# </h3>

# %%
from faker import Faker
from random import randint, sample
import datetime
import csv

# %% [markdown]
# <h3>
# Define main path of the project (Windows/Mac) where the notebooks are located
# </h3>

# %%
# Windows
#path = 'C:/Users/mzlarosa/OneDrive - unime.it/Learning/CdL Informatica/Anno II - Database/Module B/project/'

# Mac
path = '/Users/mau/OneDrive - unime.it/Learning/CdL Informatica/Anno II - Database/Module B/project/'

# %% [markdown]
# <h3>
# Create a dictionary of empty lists, where the keys are the attribute names
# </h3>

# %%
gradingSchema = ['course', 'student', 'assessment', 'score', 'attemptDate']
gradingDict = dict()
for attribute in gradingSchema:
    gradingDict[attribute] = list()
print(gradingDict)
# Out:
# {'course': [], 'student': [], 'assessment': [], 'score': [], 'attemptDate': []}

# %% [markdown]
# <h3>
# Load course table
# </h3><br>
# The <i>grading</i> table stores course, student and assessment IDs. Hence I should need to load course, student and assessment data from the respective tables. <br> Consider, anyway, that student and course IDs are also stored in the <i>enrolling</i> table, and they are exactly those that I need (a student is graded if she undergoes assessment for a course to which she is enrolled, so I need student - course correspondence from the <i>enrollment</i> table). <br> Also consider that, for some checks, I need to compare the courses to their assessment procedure, so, although course IDs could be retrieved from the <i>enrolling</i> table, I also need to load the <i>course</i> and <i>assessment</i> tables. <br> In the following code block I load the <i>course</i> table and store its data into a dictionary where the keys are the course attribute names and the values are lists with actual data.

# %%
courseDict = dict()
key = 0
with open(path + 'tables/coursesTable.csv', newline = '', encoding = 'UTF-16') as csvCourses:
    reader = csv.reader(csvCourses, delimiter = ',')
    for line in reader:
        courseDict[key] = line
        key += 1

# %%
print(courseDict)
# Out:
# {0: ['courseID', 'discipline', 'courseName', 'courseYear', 'syllabus'], 1: ['1', 'IT', 'Introduction to the Internet of Things and Embedded Systems ', '2022', 'http://learning_platform.com/introductiontotheinternetofthingsandembeddedsystems/syllabus'], 2: ['2', 'IT', 'Agile Software Development ', '2022', 'http://learning_platform.com/agilesoftwaredevelopment/syllabus'], 3: ['3', 'IT', 'Autodesk Certified Professional: AutoCAD for Design and Drafting Exam Prep ', '2022', 'http://learning_platform.com/autodeskcertifiedprofessionalautocadfordesignanddraftingexamprep/syllabus'], 4: ['4', 'IT', 'Fundamentals of Graphic Design ', '2022', 'http://learning_platform.com/fundamentalsofgraphicdesign/syllabus'], 5: ['5', 'IT', 'Java for Android ', '2022', 'http://learning_platform.com/javaforandroid/syllabus'], 6: ['6', 'IT', 'Introduction to Programming with MATLAB ', '2022', 'http://learning_platform.com/introductiontoprogrammingwithmatlab/syllabus'], 7: ['7', 'IT', 'Cryptography I ', '2022', 'http://learning_platform.com/cryptographyi/syllabus'], 8: ['8', 'IT', 'HTML, CSS, and Javascript for Web Developers ', '2022', 'http://learning_platform.com/htmlcssandjavascriptforwebdevelopers/syllabus'], 9: ['9', 'IT', 'Google Cloud Big Data and Machine Learning Fundamentals ', '2022', 'http://learning_platform.com/googlecloudbigdataandmachinelearningfundamentals/syllabus'], 10: ['10', 'IT', 'Algorithms, Part II ', '2022', 'http://learning_platform.com/algorithmspartii/syllabus'], 11: ['11', 'IT', 'Algorithms, Part I ', '2022', 'http://learning_platform.com/algorithmsparti/syllabus'], 12: ['12', 'IT', 'Divide and Conquer, Sorting and Searching, and Randomized Algorithms ', '2022', 'http://learning_platform.com/divideandconquersortingandsearchingandrandomizedalgorithms/syllabus'], 13: ['13', 'IT', 'Cloud Computing Concepts, Part 1 ', '2022', 'http://learning_platform.com/cloudcomputingconceptspart1/syllabus'], 14: ['14', 'IT', 'Programming for Everybody (Getting Started with Python) ', '2022', 'http://learning_platform.com/programmingforeverybodygettingstartedwithpython/syllabus'], 15: ['15', 'IT', 'Design and Make Infographics (Project-Centered Course) ', '2022', 'http://learning_platform.com/designandmakeinfographicsprojectcenteredcourse/syllabus'], 16: ['16', 'IT', 'Cloud Computing Basics (Cloud 101) ', '2022', 'http://learning_platform.com/cloudcomputingbasicscloud101/syllabus'], 17: ['17', 'IT', 'Hadoop Platform and Application Framework ', '2022', 'http://learning_platform.com/hadoopplatformandapplicationframework/syllabus'], 18: ['18', 'IT', 'Algorithmic Toolbox ', '2022', 'http://learning_platform.com/algorithmictoolbox/syllabus'], 19: ['19', 'IT', 'Internet History, Technology, and Security ', '2022', 'http://learning_platform.com/internethistorytechnologyandsecurity/syllabus'], 20: ['20', 'IT', 'Introduction to User Experience Design ', '2022', 'http://learning_platform.com/introductiontouserexperiencedesign/syllabus'], 21: ['21', 'IT', 'English for Career Development ', '2022', 'http://learning_platform.com/englishforcareerdevelopment/syllabus'], 22: ['22', 'IT', 'Data Visualization with Python ', '2022', 'http://learning_platform.com/datavisualizationwithpython/syllabus'], 23: ['23', 'IT', 'Computer Science: Programming with a Purpose ', '2022', 'http://learning_platform.com/computerscienceprogrammingwithapurpose/syllabus'], 24: ['24', 'IT', 'AI For Everyone ', '2022', 'http://learning_platform.com/aiforeveryone/syllabus'], 25: ['25', 'IT', 'Programming Foundations with JavaScript, HTML and CSS ', '2022', 'http://learning_platform.com/programmingfoundationswithjavascripthtmlandcss/syllabus'], 26: ['26', 'IT', 'An Introduction to Interactive Programming in Python (Part 1) ', '2022', 'http://learning_platform.com/anintroductiontointeractiveprogramminginpythonpart1/syllabus'], 27: ['27', 'IT', 'Code Yourself! An Introduction to Programming ', '2022', 'http://learning_platform.com/codeyourself!anintroductiontoprogramming/syllabus'], 28:  ...

# %%
newCourseDict = dict()
for key in courseDict[0]:
    newCourseDict[key] = list()
for i in range(1, len(courseDict)):
    newCourseDict['courseID'].append(int(courseDict[i][0]))
    newCourseDict['discipline'].append(courseDict[i][1])
    newCourseDict['courseName'].append(courseDict[i][2])
    newCourseDict['courseYear'].append(int(courseDict[i][3]))
    newCourseDict['syllabus'].append(courseDict[i][4])

# %% [markdown]
# <h3>
# Print out the result (a small sample)
# </h3>

# %%
# 50 elements from each list
print('cID', ' ' * (5 - len('cID')), 'discipline', ' ' * (15 - len('discipline')), 'courseName', ' ' * (30 - len('courseName')), 'courseYear', ' ' * (10 - len('courseYear')), 'syllabus')
for i in range(0, 50):
    cID = newCourseDict['courseID'][i]
    cat = newCourseDict['discipline'][i]
    name = newCourseDict['courseName'][i]
    year = newCourseDict['courseYear'][i]
    syll = newCourseDict['syllabus'][i]
    print(cID, ' ' * (5 - len(str(cID))), cat, ' ' * (15 - len(cat)), name[0 : 30], ' ' * (30 - len(name[0 : 30])), year, ' ' * (10 - len(str(year))), syll[0 : 40])
print('[...]')
# Out:
# cID    discipline       courseName                      courseYear  syllabus
# 1      IT               Introduction to the Internet o  2022        http://learning_platform.com/introductio
# 2      IT               Agile Software Development      2022        http://learning_platform.com/agilesoftwa
# 3      IT               Autodesk Certified Professiona  2022        http://learning_platform.com/autodeskcer
# 4      IT               Fundamentals of Graphic Design  2022        http://learning_platform.com/fundamental
# 5      IT               Java for Android                2022        http://learning_platform.com/javaforandr
# 6      IT               Introduction to Programming wi  2022        http://learning_platform.com/introductio
# 7      IT               Cryptography I                  2022        http://learning_platform.com/cryptograph
# 8      IT               HTML, CSS, and Javascript for   2022        http://learning_platform.com/htmlcssandj
# 9      IT               Google Cloud Big Data and Mach  2022        http://learning_platform.com/googlecloud
# 10     IT               Algorithms, Part II             2022        http://learning_platform.com/algorithmsp
# 11     IT               Algorithms, Part I              2022        http://learning_platform.com/algorithmsp
# 12     IT               Divide and Conquer, Sorting an  2022        http://learning_platform.com/divideandco
# 13     IT               Cloud Computing Concepts, Part  2022        http://learning_platform.com/cloudcomput
# 14     IT               Programming for Everybody (Get  2022        http://learning_platform.com/programming
# 15     IT               Design and Make Infographics (  2022        http://learning_platform.com/designandma
# 16     IT               Cloud Computing Basics (Cloud   2022        http://learning_platform.com/cloudcomput
# 17     IT               Hadoop Platform and Applicatio  2022        http://learning_platform.com/hadoopplatf
# 18     IT               Algorithmic Toolbox             2022        http://learning_platform.com/algorithmic
# 19     IT               Internet History, Technology,   2022        http://learning_platform.com/internethis
# 20     IT               Introduction to User Experienc  2022        http://learning_platform.com/introductio
# 21     IT               English for Career Development  2022        http://learning_platform.com/englishforc
# 22     IT               Data Visualization with Python  2022        http://learning_platform.com/datavisuali
# 23     IT               Computer Science: Programming   2022        http://learning_platform.com/computersci
# 24     IT               AI For Everyone                 2022        http://learning_platform.com/aiforeveryo
# 25     IT               Programming Foundations with J  2022        http://learning_platform.com/programming
# 26     IT               An Introduction to Interactive  2022        http://learning_platform.com/anintroduct
# 27     IT               Code Yourself! An Introduction  2022        http://learning_platform.com/codeyoursel
# 28     IT               Introducci\'f3n a Java          2022        http://learning_platform.com/introducci\
# 29     IT               Fundamentals of GIS             2022        http://learning_platform.com/fundamental
# 30     IT               Python and Statistics for Fina  2022        http://learning_platform.com/pythonandst
# 31     IT               Cybersecurity and Its Ten Doma  2022        http://learning_platform.com/cybersecuri
# 32     IT               Crash Course on Python          2022        http://learning_platform.com/crashcourse
# 33     IT               Design and Interpretation of C  2022        http://learning_platform.com/designandin
# 34     IT               Google Cloud Fundamentals: Cor  2022        http://learning_platform.com/googlecloud
# 35     IT               Design Thinking for Innovation  2022        http://learning_platform.com/designthink
# 36     IT               Programming Languages, Part A   2022        http://learning_platform.com/programming
# 37     IT               Introduction to Cybersecurity   2022        http://learning_platform.com/introductio
# 38     IT               How To Create a Website in a W  2022        http://learning_platform.com/howtocreate
# 39     IT               Functional Programming Princip  2022        http://learning_platform.com/functionalp
# 40     IT               SQL for Data Science            2022        http://learning_platform.com/sqlfordatas
# 41     IT               Programming Fundamentals        2022        http://learning_platform.com/programming
# 42     IT               Computer Architecture           2022        http://learning_platform.com/computerarc
# 43     IT               Build a Modern Computer         2022        http://learning_platform.com/buildamoder
# 44     IT               Getting Started with AWS Machi  2022        http://learning_platform.com/gettingstar
# 45     IT               Introduction to HTML5           2022        http://learning_platform.com/introductio
# 46     IT               Foundations of User Experience  2022        http://learning_platform.com/foundations
# 47     IT               Introduction to Google SEO      2022        http://learning_platform.com/introductio
# 48     IT               Visual Elements of User Interf  2022        http://learning_platform.com/visualeleme
# 49     IT               Fundamentals of Visualization   2022        http://learning_platform.com/fundamental
# 50     IT               Agile with Atlassian Jira       2022        http://learning_platform.com/agilewithat
# [...]

# %% [markdown]
# <h3>
# Load assessment table
# </h3><br>
# As anticipated, I also need to feed assessment IDs to the <i>grading</i> table and use it to perform some checks in conjunction with the <i>course</i> table. Hence I need to load assessment data from the <i>assessment</i> table. In the following code block I load the <i>assessment</i> table and store its data into a dictionary where the keys are the assessment attribute names and the values are lists with actual data.

# %%
assessmentDict = dict()
key = 0
with open(path + 'tables/assessmentTable.csv', newline = '', encoding = 'UTF-8') as csvAssessment:
    reader = csv.reader(csvAssessment, delimiter = ',')
    for line in reader:
        assessmentDict[key] = line
        key += 1

# %%
print(assessmentDict)
# Out:
# {0: ['assessmentID', 'assessmentType', 'name', 'thresholdScore', 'maxScore'], 1: ['1', 'quiz', 'Introduction to the Internet of Things and Embedded Systems  - Final assessment quiz', '60', '100'], 2: ['2', 'quiz', 'Agile Software Development  - Final assessment quiz', '60', '100'], 3: ['3', 'project', 'Autodesk Certified Professional: AutoCAD for Design and Drafting Exam Prep  - Final assessment project', '60', '100'], 4: ['4', 'project', 'Fundamentals of Graphic Design  - Final assessment project', '60', '100'], 5: ['5', 'project', 'Java for Android  - Final assessment project', '60', '100'], 6: ['6', 'quiz', 'Introduction to Programming with MATLAB  - Final assessment quiz', '60', '100'], 7: ['7', 'project', 'Cryptography I  - Final assessment project', '60', '100'], 8: ['8', 'project', 'HTML, CSS, and Javascript for Web Developers  - Final assessment project', '60', '100'], 9: ['9', 'project', 'Google Cloud Big Data and Machine Learning Fundamentals  - Final assessment project', '60', '100'], 10: ['10', 'quiz', 'Algorithms, Part II  - Final assessment quiz', '60', '100'], 11: ['11', 'quiz', 'Algorithms, Part I  - Final assessment quiz', '60', '100'], 12: ['12', 'quiz', 'Divide and Conquer, Sorting and Searching, and Randomized Algorithms  - Final assessment quiz', '60', '100'], 13: ['13', 'quiz', 'Cloud Computing Concepts, Part 1  - Final assessment quiz', '60', '100'], 14: ['14', 'project', 'Programming for Everybody (Getting Started with Python)  - Final assessment project', '60', '100'], 15: ['15', 'quiz', 'Design and Make Infographics (Project-Centered Course)  - Final assessment quiz', '60', '100'], 16: ['16', 'project', 'Cloud Computing Basics (Cloud 101)  - Final assessment project', '60', '100'], 17: ['17', 'project', 'Hadoop Platform and Application Framework  - Final assessment project', '60', '100'], 18: ['18', 'quiz', 'Algorithmic Toolbox  - Final assessment quiz', '60', '100'], 19: ['19', 'project', 'Internet History, Technology, and Security  - Final assessment project', '60', '100'], 20: ['20', 'project', 'Introduction to User Experience Design  - Final assessment project', '60', '100'], 21: ['21', 'project', 'English for Career Development  - Final assessment project', '60', '100'], 22: ['22', 'project', 'Data Visualization with Python  - Final assessment project', '60', '100'], 23: ['23', 'project', 'Computer Science: Programming with a Purpose  - Final assessment project', '60', '100'], 24: ['24', 'quiz', 'AI For Everyone  - Final assessment quiz', '60', '100'], 25: ['25', 'quiz', 'Programming Foundations with JavaScript, HTML and CSS  - Final assessment quiz', '60', '100'], 26: ['26', 'project', 'An Introduction to Interactive Programming in Python (Part 1)  - Final assessment project', '60', '100'], 27: ['27', 'project', 'Code Yourself! An Introduction to Programming  - Final assessment project', '60', '100'], 28: ['28', 'quiz', "Introducci\\'f3n a Java  - Final assessment quiz", '60', '100'], 29: ['29', 'quiz', 'Fundamentals of GIS  - Final assessment quiz', '60', '100'], 30: ['30', 'quiz', 'Python and Statistics for Financial Analysis  - Final assessment quiz', '60', '100'], 31: ['31', 'quiz', 'Cybersecurity and Its Ten Domains  - Final assessment quiz', '60', '100'], 32: ['32', 'project', 'Crash Course on Python  - Final assessment project', '60', '100'], 33: ['33', 'project', 'Design and Interpretation of Clinical Trials  - Final assessment project', '60', '100'], 34: ['34', 'quiz', 'Google Cloud Fundamentals: Core Infrastructure  - Final assessment quiz', '60', '100'], 35: ['35', 'project', 'Design Thinking for Innovation  - Final assessment project', '60', '100'], 36: ['36', 'quiz', 'Programming Languages, Part A  - Final assessment quiz', '60', '100'], 37: ['37', 'project', 'Introduction to Cybersecurity Tools & Cyber Attacks  - Final assessment project', '60', '100'], 38: ['38', 'project', 'How To Create a Website in a Weekend! (Project-Centered Course)  - Final assessment project', '60', '100'], ...

# %%
newAssessmentDict = dict()
for key in assessmentDict[0]:
    newAssessmentDict[key] = list()
for i in range(1, len(assessmentDict)):
    newAssessmentDict['assessmentID'].append(int(assessmentDict[i][0]))
    newAssessmentDict['assessmentType'].append(assessmentDict[i][1])
    newAssessmentDict['name'].append(assessmentDict[i][2])
    newAssessmentDict['thresholdScore'].append(int(assessmentDict[i][3]))
    newAssessmentDict['maxScore'].append(int(assessmentDict[i][4]))

# %% [markdown]
# <h3>
# Print out the result (a small sample)
# </h3>

# %%
print('aID', ' ' * (5 - len('aID')), 'aType', ' ' * (10 - len('aType')), 'name', ' ' * (70 - len('name')), 'thScore', ' ' * (8 - len('thScore')), 'maxScore', ' ' * (8 - len('maxScore')))
for i in range(0, 50):
    aID = newAssessmentDict['assessmentID'][i]
    aType = newAssessmentDict['assessmentType'][i]
    name = newAssessmentDict['name'][i]
    thScore = newAssessmentDict['thresholdScore'][i]
    maxScore = newAssessmentDict['maxScore'][i]
    print(aID, ' ' * (5 - len(str(aID))), aType, ' ' * (10 - len(aType)), name[0 : 65], ' ' * (70 - len(name[0 : 65])), thScore, ' ' * (8 - len(str(thScore))), maxScore, ' ' * (8 - len(str(maxScore))))
# Out:
# aID    aType       name                                                                    thScore   maxScore
# 1      quiz        Introduction to the Internet of Things and Embedded Systems  - Fi       60        100
# 2      quiz        Agile Software Development  - Final assessment quiz                     60        100
# 3      project     Autodesk Certified Professional: AutoCAD for Design and Drafting        60        100
# 4      project     Fundamentals of Graphic Design  - Final assessment project              60        100
# 5      project     Java for Android  - Final assessment project                            60        100
# 6      quiz        Introduction to Programming with MATLAB  - Final assessment quiz        60        100
# 7      project     Cryptography I  - Final assessment project                              60        100
# 8      project     HTML, CSS, and Javascript for Web Developers  - Final assessment        60        100
# 9      project     Google Cloud Big Data and Machine Learning Fundamentals  - Final        60        100
# 10     quiz        Algorithms, Part II  - Final assessment quiz                            60        100
# 11     quiz        Algorithms, Part I  - Final assessment quiz                             60        100
# 12     quiz        Divide and Conquer, Sorting and Searching, and Randomized Algorit       60        100
# 13     quiz        Cloud Computing Concepts, Part 1  - Final assessment quiz               60        100
# 14     project     Programming for Everybody (Getting Started with Python)  - Final        60        100
# 15     quiz        Design and Make Infographics (Project-Centered Course)  - Final a       60        100
# 16     project     Cloud Computing Basics (Cloud 101)  - Final assessment project          60        100
# 17     project     Hadoop Platform and Application Framework  - Final assessment pro       60        100
# 18     quiz        Algorithmic Toolbox  - Final assessment quiz                            60        100
# 19     project     Internet History, Technology, and Security  - Final assessment pr       60        100
# 20     project     Introduction to User Experience Design  - Final assessment projec       60        100
# 21     project     English for Career Development  - Final assessment project              60        100
# 22     project     Data Visualization with Python  - Final assessment project              60        100
# 23     project     Computer Science: Programming with a Purpose  - Final assessment        60        100
# 24     quiz        AI For Everyone  - Final assessment quiz                                60        100
# 25     quiz        Programming Foundations with JavaScript, HTML and CSS  - Final as       60        100
# 26     project     An Introduction to Interactive Programming in Python (Part 1)  -        60        100
# 27     project     Code Yourself! An Introduction to Programming  - Final assessment       60        100
# 28     quiz        Introducci\'f3n a Java  - Final assessment quiz                         60        100
# 29     quiz        Fundamentals of GIS  - Final assessment quiz                            60        100
# 30     quiz        Python and Statistics for Financial Analysis  - Final assessment        60        100
# 31     quiz        Cybersecurity and Its Ten Domains  - Final assessment quiz              60        100
# 32     project     Crash Course on Python  - Final assessment project                      60        100
# 33     project     Design and Interpretation of Clinical Trials  - Final assessment        60        100
# 34     quiz        Google Cloud Fundamentals: Core Infrastructure  - Final assessmen       60        100
# 35     project     Design Thinking for Innovation  - Final assessment project              60        100
# 36     quiz        Programming Languages, Part A  - Final assessment quiz                  60        100
# 37     project     Introduction to Cybersecurity Tools & Cyber Attacks  - Final asse       60        100
# 38     project     How To Create a Website in a Weekend! (Project-Centered Course)         60        100
# 39     project     Functional Programming Principles in Scala  - Final assessment pr       60        100
# 40     project     SQL for Data Science  - Final assessment project                        60        100
# 41     quiz        Programming Fundamentals  - Final assessment quiz                       60        100
# 42     project     Computer Architecture  - Final assessment project                       60        100
# 43     project     Build a Modern Computer  - Final assessment project                     60        100
# 44     project     Getting Started with AWS Machine Learning  - Final assessment pro       60        100
# 45     quiz        Introduction to HTML5  - Final assessment quiz                          60        100
# 46     project     Foundations of User Experience (UX) Design  - Final assessment pr       60        100
# 47     project     Introduction to Google SEO  - Final assessment project                  60        100
# 48     quiz        Visual Elements of User Interface Design  - Final assessment quiz       60        100
# 49     quiz        Fundamentals of Visualization with Tableau  - Final assessment qu       60        100
# 50     quiz        Agile with Atlassian Jira  - Final assessment quiz                      60        100

# %% [markdown]
# <h3>
# Load enrolling table
# </h3><br>
# Each student can be enrolled in one or more courses (or zero courses). Each course has a final assessment. For each enrollment (enrollment is defined as a tuple student - course), it is possible that there is an assessment by the student. So the maximum possible assessments performed would be equal to the number of enrollments. I need to load the <i>enrolling</i> table in which I have stored courses to which students are enrolled.

# %%
enrollingDict = dict()
key = 0
with open(path + 'tables/enrollingTable.csv', newline = '', encoding = 'UTF-8') as csvEnrolling:
    reader = csv.reader(csvEnrolling, delimiter = ',')
    for line in reader:
        enrollingDict[key] = line
        key += 1

# %%
print(enrollingDict)
# Out:
# {0: ['course', 'student', 'enrollDate'], 1: ['150', '2', '2023-6-20'], 2: ['314', '2', '2022-11-2'], 3: ['296', '2', '2023-5-31'], 4: ['195', '2', '2022-9-12'], 5: ['132', '3', '2022-6-13'], 6: ['432', '3', '2023-6-25'], 7: ['93', '3', '2022-5-31'], 8: ['222', '3', '2023-2-11'], 9: ['395', '3', '2023-3-16'], 10: ['207', '4', '2022-3-6'], 11: ['291', '5', '2022-5-11'], 12: ['277', '8', '2023-7-18'], 13: ['299', '8', '2022-4-20'], 14: ['380', '9', '2023-6-17'], 15: ['369', '9', '2022-3-28'], 16: ['21', '9', '2022-5-16'], 17: ['245', '9', '2023-4-18'], 18: ['338', '9', '2023-2-14'], 19: ['24', '11', '2023-6-12'], 20: ['10', '12', '2022-1-3'], 21: ['12', '12', '2022-10-2'], 22: ['23', '12', '2022-8-2'], 23: ['181', '12', '2022-12-6'], 24: ['298', '12', '2023-1-7'], 25: ['347', '13', '2023-2-10'], 26: ['433', '16', '2023-7-21'], 27: ['257', '17', '2022-1-23'], 28: ['245', '17', '2022-12-28'], 29: ['401', '18', '2022-10-12'], 30: ['384', '19', '2022-4-27'], 31: ['213', '19', '2022-5-2'], 32: ['367', '20', '2022-5-16'], 33: ['102', '21', '2022-9-16'], 34: ['355', '21', '2023-3-24'], 35: ['47', '21', '2023-3-5'], 36: ['425', '21', '2022-9-26'], 37: ['184', '23', '2022-8-27'], 38: ['69', '23', '2022-9-1'], 39: ['285', '24', '2023-5-30'], 40: ['90', '24', '2023-7-10'], 41: ['468', '24', '2022-2-11'], 42: ['246', '25', '2022-4-26'], 43: ['193', '25', '2022-2-5'], 44: ['125', '25', '2022-7-28'], 45: ['221', '25', '2023-2-16'], 46: ['62', '25', '2022-12-10'], 47: ['126', '26', '2022-7-31'], 48: ['426', '26', '2022-9-12'], 49: ['300', '26', '2023-7-20'], 50: ['428', '26', '2022-5-31'], 51: ['9', '26', '2022-9-17'], 52: ['39', '27', '2022-5-29'], 
# <h3>
# Print out result (a small sample)
# </h3>

# %%
print('course', ' ' * (10 - len('course')), 'student', ' ' * (10 - len('student')), 'enrollDate')
for i in range(0, 50):
    course = newEnrollingDict['course'][i]
    student = newEnrollingDict['student'][i]
    date = newEnrollingDict['enrollDate'][i]
    print(course, ' ' * (10 - len(str(course))), student, ' ' * (10 - len(str(student))), date)
# Out:
# course      student     enrollDate
# 150         2           2023-6-20
# 314         2           2022-11-2
# 296         2           2023-5-31
# 195         2           2022-9-12
# 132         3           2022-6-13
# 432         3           2023-6-25
# 93          3           2022-5-31
# 222         3           2023-2-11
# 395         3           2023-3-16
# 207         4           2022-3-6
# 291         5           2022-5-11
# 277         8           2023-7-18
# 299         8           2022-4-20
# 380         9           2023-6-17
# 369         9           2022-3-28
# 21          9           2022-5-16
# 245         9           2023-4-18
# 338         9           2023-2-14
# 24          11          2023-6-12
# 10          12          2022-1-3
# 12          12          2022-10-2
# 23          12          2022-8-2
# 181         12          2022-12-6
# 298         12          2023-1-7
# 347         13          2023-2-10
# 433         16          2023-7-21
# 257         17          2022-1-23
# 245         17          2022-12-28
# 401         18          2022-10-12
# 384         19          2022-4-27
# 213         19          2022-5-2
# 367         20          2022-5-16
# 102         21          2022-9-16
# 355         21          2023-3-24
# 47          21          2023-3-5
# 425         21          2022-9-26
# 184         23          2022-8-27
# 69          23          2022-9-1
# 285         24          2023-5-30
# 90          24          2023-7-10
# 468         24          2022-2-11
# 246         25          2022-4-26
# 193         25          2022-2-5
# 125         25          2022-7-28
# 221         25          2023-2-16
# 62          25          2022-12-10
# 126         26          2022-7-31
# 426         26          2022-9-12
# 300         26          2023-7-20
# 428         26          2022-5-31

# %% [markdown]
# The above cell shows the courses to which students are enrolled ( a sample of them, actually). It is hard to imagine, though, that all students enrolled to courses have undergone an assessment for each course to which they are enrolled. So, there must be introduced a way to sample through the enrollments and attach an assessment only to those included in the sample.

# %% [markdown]
# <h3>
# Max assessments scenario
# </h3><br>
# I first explore the case with maximum possible assessments, implemented through the following code.
# Notice that I introduce a mechanism to ensure that the grading date is at least one month after a student has enrolled to the course of interest (assuming the course forces a sort of minimum time spent studying before being admitted to grading):
#
#     datetime.date(year, month, day) + datetime.timedelta(30)
#
# Also, by introducing the end date:
#
#     datetime.date(2023, 8, 31)
#
# I ensure that, if the enrollment date is the maximum one (july 30th, 2023), the assessment date is max august 30th, 2023 since I want the status of the platform to be freezed at the end of august (since the exam should be due for september).

# %% [markdown]
# <h4>
# Check course - assessment correspondence
# </h4><br>
# I need to check that course IDs and assessment IDs are the same because I associate course enrollment by a student to course assessment. So, if there weren't exact correspondence, a student enrolled to a course would be assessed on the assessment of another course.

# %%
checkSum = 0
for course, assessment in zip(newCourseDict['courseID'], newAssessmentDict['assessmentID']):
    if course == assessment:
        checkSum += 1
    else:
        print('course ID:', course, 'assessment ID:', assessment)
print('number of courses:', len(newCourseDict['courseID']), '\nnumber of assessments:', len(newAssessmentDict['assessmentID']), '\nnumber of course - assessment correspondences:', checkSum)
# Out:
# number of courses: 480
# number of assessments: 480
# number of course - assessment correspondences: 480

# %%
for student, course, date in zip(newEnrollingDict['student'], newEnrollingDict['course'], newEnrollingDict['enrollDate']):
    gradingDict['student'].append(student)
    gradingDict['course'].append(course)
    #by construction course IDs and assessment IDs are the same (I also checked it in the previous cell)
    for cID, c, aID, a in zip(newCourseDict['courseID'], newCourseDict['courseName'], newAssessmentDict['assessmentID'], newAssessmentDict['name']):
        if course == cID:
            gradingDict['assessment'].append(aID)
    gradingDict['score'].append(randint(40, 100))
    
    # make enrolling date readable by the datetime module
    fake = Faker()
    dateList = date.split('-')
    year = int(dateList[0])
    month = int(dateList[1])
    day = int(dateList[2])
    gradingDict['attemptDate'].append(fake.date_between(datetime.date(year, month, day) + datetime.timedelta(30), datetime.date(2023, 8, 31)))

# %%
# print the number of elements of each list in the dictionary (this should be equal to the number of enrollments)
sLen = 0
cLen = 0
aLen = 0
for s, c, a in zip(gradingDict['student'], gradingDict['course'], gradingDict['assessment']):
    sLen += 1
    cLen += 1
    aLen += 1
print(sLen, cLen, aLen, len(newEnrollingDict['course']))
# Out:
# 239 239 239 239

# %% [markdown]
# <h3>
# Print out result (max assessment scenario)
# </h3>

# %%
# print the elements of each list in the dictionary
counter = 0
print('counter', ' ' * (8 - len('counter')), 'sID', ' ' * (5 - len('sID')), 'cID', ' ' * (5 - len('cID')), 'aID', ' ' * (5 - len('aID')), 'score', ' ' * (10 - len('score')), 'enrollDate', ' ' * (15 - len('enrollDate')), 'gradingDate')
for sID, cID, aID, score, eDate, aDate in zip(gradingDict['student'], gradingDict['course'], gradingDict['assessment'], gradingDict['score'], newEnrollingDict['enrollDate'], gradingDict['attemptDate']):
    counter += 1
    print(counter, ' ' * (8 - len(str(counter))), sID, ' ' * (5 - len(str(sID))), cID, ' ' * (5 - len(str(cID))), aID, ' ' * (5 - len(str(aID))), score, ' ' * (10 - len(str(score))), eDate, ' ' * (15 - len(eDate)), aDate)
# Out:
# counter   sID    cID    aID    score       enrollDate       gradingDate
# 1         2      150    150    45          2023-6-20        2023-08-09
# 2         2      314    314    53          2022-11-2        2023-04-11
# 3         2      296    296    72          2023-5-31        2023-08-02
# 4         2      195    195    93          2022-9-12        2023-04-28
# 5         3      132    132    57          2022-6-13        2022-09-13
# 6         3      432    432    87          2023-6-25        2023-07-29
# 7         3      93     93     50          2022-5-31        2023-05-28
# 8         3      222    222    99          2023-2-11        2023-06-22
# 9         3      395    395    61          2023-3-16        2023-07-03
# 10        4      207    207    98          2022-3-6         2023-03-26
# 11        5      291    291    61          2022-5-11        2022-09-09
# 12        8      277    277    58          2023-7-18        2023-08-21
# 13        8      299    299    42          2022-4-20        2023-02-08
# 14        9      380    380    78          2023-6-17        2023-08-02
# 15        9      369    369    91          2022-3-28        2023-04-20
# 16        9      21     21     71          2022-5-16        2022-09-15
# 17        9      245    245    78          2023-4-18        2023-07-22
# 18        9      338    338    47          2023-2-14        2023-07-09
# 19        11     24     24     55          2023-6-12        2023-07-31
# 20        12     10     10     100         2022-1-3         2023-03-21
# 21        12     12     12     75          2022-10-2        2023-05-23
# 22        12     23     23     82          2022-8-2         2022-09-27
# 203       89     276    276    45          2022-1-1         2022-12-31
# 204       89     32     32     47          2022-11-20       2023-05-22
# 205       89     85     85     59          2022-8-23        2023-05-23
# 206       90     329    329    72          2023-6-16        2023-08-16
# 207       92     285    285    87          2022-3-17        2022-10-24
# 208       92     351    351    95          2022-4-1         2022-06-18
# 209       92     165    165    86          2022-11-16       2023-04-27
# 210       92     66     66     40          2023-5-21        2023-07-13
# 211       92     74     74     92          2022-11-28       2023-02-13
# 212       93     456    456    67          2022-11-13       2023-03-10
# 213       93     287    287    74          2022-10-22       2023-06-20
# 214       93     212    212    54          2023-5-20        2023-06-21
# 215       93     82     82     70          2022-1-27        2022-12-17
# 216       93     378    378    95          2022-11-20       2023-02-03
# 217       94     165    165    78          2022-2-10        2022-06-05
# 218       94     276    276    48          2022-7-2         2023-02-13
# 219       94     103    103    80          2022-3-26        2023-07-23
# 220       94     43     43     45          2022-3-12        2023-04-06
# 221       94     121    121    95          2022-11-27       2023-08-14
# 222       95     34     34     68          2022-6-19        2022-08-30
# 223       95     237    237    57          2022-4-19        2022-11-12
# 224       95     296    296    45          2023-7-19        2023-08-19
# 225       95     6      6      47          2023-2-7         2023-08-17
# 226       96     20     20     87          2022-3-28        2022-10-05
# 227       96     81     81     64          2022-5-14        2022-10-15
# 228       96     214    214    49          2022-2-24        2022-07-14
# 229       96     43     43     56          2022-6-27        2023-02-02
# 230       97     313    313    57          2022-11-29       2023-04-02
# 231       97     256    256    85          2022-2-25        2023-03-23
# 232       97     379    379    91          2022-12-5        2023-06-03
# 233       97     314    314    60          2022-5-23        2022-09-04
# 234       98     227    227    87          2022-5-31        2023-04-14
# 235       99     288    288    98          2022-10-26       2022-12-03
# 236       99     408    408    41          2023-6-10        2023-07-18
# 237       99     193    193    99          2023-7-22        2023-08-21
# 238       100    328    328    51          2022-10-31       2023-08-08
# 239       100    72     72     83          2022-1-5         2022-12-06

# %% [markdown]
# <h3>
# Sampled assessments scenario
# </h3><br>
# Then I try to sample out some random assessments from the previous scenario, to simulate the fact that not all students may have undergone assessment for each course in which they are enrolled. I decide a percentage of enrollments that I want to sample out from the <i>grading</i> table. Then I compute its inverse, which is in fact the percentage of enrollments that I want to have undergone assessment and I translate that percentage into an integer number, that is the exact number of elements that I want to keep in the <i>grading</i> table. However, it works better to create a new dictionary and append to its lists these elements. Then I will use this dictionary instead of the original one.

# %%
# I want 20% of all of the enrollments not to have an assessment (which means I want 80% to have an assessment)
end = len(gradingDict['student'])
sampleIn = list()
while len(sampleIn) < int(end * 0.8):
    randomNumber = randint(0, end)
    if randomNumber not in sampleIn:
        sampleIn.append(randomNumber) 
# notice that sampling is without replacement, hence there can be int(end * 0.8) gradings, one per enrollment

# %% [markdown]
# I generate a new empty dictionary with the same keys as the gradingDict and fill it with elements from gradingDict located at the positions stored in the list <i>sampleIn</i>. This will be my new grading table.

# %%
newGradingDict = dict()
for k in gradingDict.keys():
    newGradingDict[k] = list()

# %%
for i in range(0, end):
    if i in sampleIn:
        newGradingDict['course'].append(gradingDict['course'][i])
        newGradingDict['student'].append(gradingDict['student'][i])
        newGradingDict['assessment'].append(gradingDict['assessment'][i])
        newGradingDict['score'].append(gradingDict['score'][i])
        newGradingDict['attemptDate'].append(gradingDict['attemptDate'][i])

# %% [markdown]
# <h3>
# Print out result (sampled assessment scenario)
# </h3>

# %%
#I show the elements of the new gradingDict
counter1 = 0
print('counter', ' ' * (8 - len('counter')), 'sID', ' ' * (5 - len('sID')), 'cID', ' ' * (5 - len('cID')), 'aID', ' ' * (5 - len('aID')), 'score', ' ' * (10 - len('score')), 'gradingDate')   
for sID, cID, aID, score, aDate in zip(newGradingDict['student'], newGradingDict['course'], newGradingDict['assessment'], newGradingDict['score'], newGradingDict['attemptDate']):
    counter1 += 1
    print(counter1, ' ' * (8 - len(str(counter1))), sID, ' ' * (5 - len(str(sID))), cID, ' ' * (5 - len(str(cID))), aID, ' ' * (5 - len(str(aID))), score, ' ' * (10 - len(str(score))), aDate)
# Out:
# counter   sID    cID    aID    score       gradingDate
# 1         2      150    150    45          2023-08-09
# 2         2      195    195    93          2023-04-28
# 3         3      132    132    57          2022-09-13
# 4         3      432    432    87          2023-07-29
# 5         3      93     93     50          2023-05-28
# 6         3      222    222    99          2023-06-22
# 7         3      395    395    61          2023-07-03
# 8         4      207    207    98          2023-03-26
# 9         5      291    291    61          2022-09-09
# 10        9      21     21     71          2022-09-15
# 11        9      245    245    78          2023-07-22
# 12        9      338    338    47          2023-07-09
# 13        11     24     24     55          2023-07-31
# 14        12     10     10     100         2023-03-21
# 15        12     23     23     82          2022-09-27
# 16        12     181    181    93          2023-05-06
# 17        12     298    298    56          2023-03-26
# 18        13     347    347    81          2023-08-07
# 19        17     257    257    100         2023-03-22
# 20        17     245    245    65          2023-04-30
# 21        18     401    401    44          2023-04-17
# 22        19     384    384    57          2023-06-12
# 23        20     367    367    63          2023-05-02
# 24        21     102    102    58          2022-11-04
# 25        21     355    355    98          2023-08-27
# 26        21     47     47     75          2023-05-21
# 27        21     425    425    83          2023-05-24
# 28        23     184    184    89          2023-07-03
# 29        23     69     69     45          2023-01-26
# 30        24     90     90     92          2023-08-25
# 31        24     468    468    73          2022-10-19
# 32        25     246    246    79          2023-04-20
# 33        25     193    193    90          2022-10-15
# 34        25     125    125    58          2023-04-01
# 35        25     221    221    92          2023-07-05
# 36        25     62     62     50          2023-05-03
# 37        26     126    126    100         2023-08-11
# 38        26     300    300    88          2023-08-22
# 39        26     9      9      77          2023-02-08
# 40        27     39     39     40          2022-11-06
# 41        27     14     14     53          2023-01-17
# 42        27     314    314    91          2022-12-19
# 43        27     431    431    100         2023-06-11
# 44        28     126    126    91          2023-07-25
# 45        28     346    346    94          2023-07-28
# 46        29     322    322    72          2023-04-14
# 47        30     431    431    88          2022-07-31
# 48        31     410    410    43          2023-03-10
# 49        32     156    156    67          2023-06-02
# 50        32     438    438    59          2022-12-01
# 51        32     466    466    91          2023-07-30
# 52        32     426    426    48          2023-03-29
# 53        33     175    175    62          2022-09-10
# 54        33     126    126    41          2023-06-01
# 55        33     96     96     61          2023-03-22
# 56        33     396    396    61          2023-03-08
# 57        33     390    390    84          2023-08-08
# 140       75     267    267    73          2022-07-10
# 141       75     69     69     83          2023-08-05
# 142       75     350    350    45          2023-02-24
# 143       75     212    212    89          2023-07-22
# 144       76     267    267    44          2022-08-31
# 145       76     272    272    81          2023-07-11
# 146       78     344    344    99          2023-07-04
# 147       78     179    179    49          2022-09-28
# 148       80     104    104    96          2023-04-18
# 149       81     480    480    50          2023-06-26
# 150       81     232    232    55          2023-08-25
# 151       81     185    185    45          2023-07-01
# 152       82     151    151    49          2022-08-16
# 153       82     220    220    57          2023-04-03
# 154       82     318    318    81          2023-05-20
# 155       84     273    273    49          2023-08-25
# 156       85     150    150    80          2023-06-28
# 157       85     463    463    67          2023-01-15
# 158       87     220    220    84          2023-06-12
# 159       87     395    395    81          2023-08-27
# 160       87     118    118    61          2023-06-12
# 161       87     99     99     62          2023-08-19
# 162       88     362    362    77          2023-08-22
# 163       89     276    276    45          2022-12-31
# 164       89     32     32     47          2023-05-22
# 165       89     85     85     59          2023-05-23
# 166       90     329    329    72          2023-08-16
# 167       92     285    285    87          2022-10-24
# 168       92     66     66     40          2023-07-13
# 169       92     74     74     92          2023-02-13
# 170       93     456    456    67          2023-03-10
# 171       93     287    287    74          2023-06-20
# 172       93     212    212    54          2023-06-21
# 173       94     165    165    78          2022-06-05
# 174       94     276    276    48          2023-02-13
# 175       94     103    103    80          2023-07-23
# 176       94     43     43     45          2023-04-06
# 177       94     121    121    95          2023-08-14
# 178       95     296    296    45          2023-08-19
# 179       95     6      6      47          2023-08-17
# 180       96     20     20     87          2022-10-05
# 181       96     214    214    49          2022-07-14
# 182       96     43     43     56          2023-02-02
# 183       97     256    256    85          2023-03-23
# 184       97     379    379    91          2023-06-03
# 185       97     314    314    60          2022-09-04
# 186       98     227    227    87          2023-04-14
# 187       99     288    288    98          2022-12-03
# 188       99     408    408    41          2023-07-18
# 189       99     193    193    99          2023-08-21
# 190       100    72     72     83          2022-12-06

# %% [markdown]
# <h3>
# Multiple sampled assessments scenario
# </h3><br>
# Now I want to implement the possibility that a student has undergone assessment more than once for a course to which she is enrolled, because its grading score was not sufficient to obtain the course certificate. I consider only tuples with grading scores less than 60 and sample some of them to replicate studentID, courseID and assessmentID but with a new score (not necessarily different from the one already in newGradingDict) and a new date, necessarily following the one already present in newGradingDict and preceding august 31st, 2023.

# %% [markdown]
# First of all I count the number of grading tuples with scores under 60. Then I compute a maximum percentage of tuples with scores under 60 where the student may have been assessed more than once, say 80%. Then I generate random numbers up to that 80%. Then I perform iterations in the new grading table and duplicate grading tuples if the ith iteration is equal to one of those random numbers.

# %%
counter2 = 0
for i in newGradingDict['student']:
    counter2 += 1
print(counter2)
# Out:
# 190

# %% [markdown]
# Then I compute the 80% of the counter (as an integer) and fill a list with random numbers up to that integer. Random numbers must not be replicated within the list, so that I obtain exactly a list length of 80% the value of the counter.

# %%
sampleDuplicate = list()
while len(sampleDuplicate) < int(counter2 * 0.8):
    randomDuplicate = randint(0, counter2)
    if randomDuplicate not in sampleDuplicate:
        sampleDuplicate.append(randomDuplicate)
print(len(sampleDuplicate))
print(sampleDuplicate, end = '')
# Out:
# 152
# [18, 110, 140, 63, 177, 33, 92, 176, 105, 163, 125, 115, 52, 5, 64, 0, 122, 11, 72, 108, 139, 89, 56, 102, 71, 43, 26, 68, 154, 9, 42, 137, 88, 19, 187, 149, 107, 101, 35, 168, 13, 172, 47, 131, 175, 27, 159, 59, 82, 182, 169, 94, 116, 188, 30, 189, 100, 180, 179, 99, 79, 145, 135, 61, 181, 158, 153, 97, 87, 173, 178, 83, 23, 34, 152, 185, 41, 74, 44, 57, 91, 86, 166, 146, 157, 141, 84, 29, 118, 114, 38, 2, 165, 113, 133, 75, 17, 129, 21, 32, 120, 136, 143, 73, 174, 62, 25, 40, 20, 48, 76, 109, 80, 160, 126, 171, 8, 37, 147, 54, 46, 36, 67, 119, 65, 95, 77, 162, 121, 123, 4, 156, 151, 150, 134, 93, 7, 6, 142, 28, 24, 117, 15, 90, 50, 167, 111, 45, 96, 155, 85, 130]

# %% [markdown]
# Then I iterate through the grading table until a length of 80% of the counter would be reached. When the value of 'score' within the actual grading tuple is less than the threshold and the position is included in the 80% sample list, I generate a new score and a date later than the previous assessment. I introduce October 15th, 2023, otherwise there is the chance that the previous assessment had taken place in August and would exceed the previously fixed limit date of August 31st, 2023.
# It is to be noticed that, since two conditions are needed (the score to be under 60 and the position to be included in the 80% sample), it is hard that all 80% tuples sampled would respect both conditions. Hence, the number of extra assessments should normally be well under 80% of the insufficient scores and there's no way to predict this number exactly.

# %%
counter3 = 0
for c, s, a, sc, ad in zip(newGradingDict['course'], newGradingDict['student'], newGradingDict['assessment'], newGradingDict['score'], newGradingDict['attemptDate']):
    if sc < 60 and counter3 in sampleDuplicate:
        newGradingDict['course'].append(c)
        newGradingDict['student'].append(s)
        newGradingDict['assessment'].append(a)
        newGradingDict['score'].append(randint(40, 100))
        strDate = str(ad)
        dateList1 = strDate.split('-')
        year1 = int(dateList1[0])
        month1 = int(dateList1[1])
        day1 = int(dateList1[2])
        newGradingDict['attemptDate'].append(fake.date_between(datetime.date(year1, month1, day1) + datetime.timedelta(15), datetime.date(2023, 10, 16)))
    counter3 += 1

# %% [markdown]
# <h3>
# Print out result (multiple sampled assessment scenario)
# </h3>

# %%
#I show the elements of the new gradingDict
counter4 = 0
print('counter', ' ' * (8 - len('counter')), 'sID', ' ' * (5 - len('sID')), 'cID', ' ' * (5 - len('cID')), 'aID', ' ' * (5 - len('aID')), 'score', ' ' * (10 - len('score')), 'gradingDate')   
for sID, cID, aID, score, aDate in zip(newGradingDict['student'], newGradingDict['course'], newGradingDict['assessment'], newGradingDict['score'], newGradingDict['attemptDate']):
    counter4 += 1
    print(counter4, ' ' * (8 - len(str(counter4))), sID, ' ' * (5 - len(str(sID))), cID, ' ' * (5 - len(str(cID))), aID, ' ' * (5 - len(str(aID))), score, ' ' * (10 - len(str(score))), aDate)
# Out:
# counter   sID    cID    aID    score       gradingDate
# 1         2      150    150    45          2023-08-09
# 2         2      195    195    93          2023-04-28
# 3         3      132    132    57          2022-09-13
# 4         3      432    432    87          2023-07-29
# 5         3      93     93     50          2023-05-28
